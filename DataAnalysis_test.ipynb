# %% [markdown]
# Import DATABASE: (vendas.xlsx)

# %%
import pandas as pd

table = pd.read_excel("DB/vendas.xlsx")

# %% [markdown]
# Get overview of information.

# %%
total_billing = table["Valor Final"].sum()
total_sales = table["Quantidade"].sum()

print('TOTAL R$: '+str(total_billing))
print("TOTAL Amount: "+str(total_sales))
# Out:
# TOTAL R$: 55895
# TOTAL Amount: 350

# %% [markdown]
# Analyze Top-> Down

# %%
#billing per store and items amount
billing_per_store = table[["ID Loja","Valor Final","Quantidade"]].groupby("ID Loja").sum("Valor Final")
display(billing_per_store)
# Out:
#                             Valor Final  Quantidade
# ID Loja
# Bourbon Shopping SP                4386          27
# Center Shopping Uberlândia         2994          18
# Iguatemi Campinas                 41720         264
# Iguatemi Esplanada                 2473          14
# Norte Shopping                     4322          27

# %%
#Enter the details
billing_product = table[["ID Loja","Produto","Valor Final"]].groupby(["ID Loja", "Produto"]).sum()
display(billing_product)
# Out:
#                                              Valor Final
# ID Loja                    Produto
# Bourbon Shopping SP        Bermuda                   750
#                            Bermuda Estampa          1183
#                            Bermuda Linho             195
#                            Bermuda Listrado         1793
#                            Bermuda Xadrez            465
# Center Shopping Uberlândia Bermuda Estampa           338
#                            Bermuda Linho             780
#                            Bermuda Listrado          326
#                            Bermuda Xadrez           1550
# Iguatemi Campinas          Bermuda                  1200
#                            Bermuda Estampa           845
#                            Bermuda Linho            1170
#                            Bermuda Liso            36581
#                            Bermuda Listrado         1304
#                            Bermuda Xadrez            620
# ...

# %% [markdown]
# Graphics

# %%
products = table[["Produto","Quantidade"]].groupby("Produto").sum("Quantidade")
df = pd.DataFrame(products)

# %% [markdown]
# Best selling items

# %%
df.plot.pie(y='Quantidade',figsize=(20, 15),autopct="%.2f")
# Out:
# <AxesSubplot:ylabel='Quantidade'>

# %% [markdown]
# SHOW TABLE INFOS

# %%
display(table)
# Out:
#          Data                     ID Loja           Produto  Quantidade  \
# 0  2019-12-01           Iguatemi Campinas   Bermuda Estampa           1
# 1  2019-12-01          Iguatemi Esplanada    Bermuda Xadrez           1
# 2  2019-12-01              Norte Shopping           Bermuda           2
# 3  2019-12-01           Iguatemi Campinas  Bermuda Listrado           3
# 4  2019-12-01           Iguatemi Campinas     Bermuda Linho           3
# 5  2019-12-03           Iguatemi Campinas    Bermuda Xadrez           1
# 6  2019-12-03         Bourbon Shopping SP  Bermuda Listrado           1
# 7  2019-12-03         Bourbon Shopping SP    Bermuda Xadrez           3
# 8  2019-12-03         Bourbon Shopping SP   Bermuda Estampa           1
# 9  2019-12-04  Center Shopping Uberlândia    Bermuda Xadrez           4
# 10 2019-12-04          Iguatemi Esplanada           Bermuda           1
# 11 2019-12-04         Bourbon Shopping SP   Bermuda Estampa           2
# ...
